# %%
import pandas as pd
import seaborn as sns

# %%
file_path_train = 'train.csv'
file_path_labels = 'train_labels.csv'

# %%
test_data = pd.read_csv(file_path_train)
test_labels = pd.read_csv(file_path_labels)
full_data = pd.merge(test_labels, test_data, on = 'sequence')

# %%
sensor_columns = full_data.columns[4:]

# %%
full_data.head()
# Out:
#    sequence  state  subject  step  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0      0       47     0  -0.196291   0.112395        1.0   0.329204
# 1         0      0       47     1  -0.447450   0.134454        1.0  -0.658407
# 2         0      0       47     2   0.326893  -0.694328        1.0   0.330088
# 3         0      0       47     3   0.523184   0.751050        1.0   0.976991
# 4         0      0       47     4   0.272025   1.074580        1.0  -0.136283
#
#    sensor_04  sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# 0  -1.004660  -0.131638  -0.127505   0.368702       -0.1  -0.963873
# 1   0.162495   0.340314  -0.209472  -0.867176        0.2  -0.301301
# 2   0.473678   1.280479  -0.094718   0.535878        1.4   1.002168
# 3  -0.563287  -0.720269   0.793260   0.951145       -0.3  -0.995665
# 4   0.398579   0.044877   0.560109  -0.541985       -0.9   1.055636
#
#    sensor_10  sensor_11  sensor_12
# 0  -0.985069   0.531893   4.751492
# 1   0.082733  -0.231481   0.454390
# 2   0.449221  -0.586420  -4.736147
# 3  -0.434290   1.344650   0.429241
# 4   0.812631   0.123457  -0.223359

# %%
chg_data = full_data.groupby('sequence')[sensor_columns].shift(1)
chg_data.columns = [col + '_chg' for col in chg_data.columns]

# %%
combined_data = pd.concat([full_data, chg_data], axis = 1)

# %%
combined_data.head()
# Out:
#    sequence  state  subject  step  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0      0       47     0  -0.196291   0.112395        1.0   0.329204
# 1         0      0       47     1  -0.447450   0.134454        1.0  -0.658407
# 2         0      0       47     2   0.326893  -0.694328        1.0   0.330088
# 3         0      0       47     3   0.523184   0.751050        1.0   0.976991
# 4         0      0       47     4   0.272025   1.074580        1.0  -0.136283
#
#    sensor_04  sensor_05  ...  sensor_03_chg  sensor_04_chg  sensor_05_chg  \
# 0  -1.004660  -0.131638  ...            NaN            NaN            NaN
# 1   0.162495   0.340314  ...       0.329204      -1.004660      -0.131638
# 2   0.473678   1.280479  ...      -0.658407       0.162495       0.340314
# 3  -0.563287  -0.720269  ...       0.330088       0.473678       1.280479
# 4   0.398579   0.044877  ...       0.976991      -0.563287      -0.720269
#
#    sensor_06_chg  sensor_07_chg  sensor_08_chg  sensor_09_chg  sensor_10_chg  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1      -0.127505       0.368702           -0.1      -0.963873      -0.985069
# 2      -0.209472      -0.867176            0.2      -0.301301       0.082733
# 3      -0.094718       0.535878            1.4       1.002168       0.449221
# 4       0.793260       0.951145           -0.3      -0.995665      -0.434290
#
#    sensor_11_chg  sensor_12_chg
# 0            NaN            NaN
# 1       0.531893       4.751492
# 2      -0.231481       0.454390
# 3      -0.586420      -4.736147
# 4       1.344650       0.429241
#
# [5 rows x 30 columns]

# %% [markdown]
# # Noticing we need to group by sequences and do calcs from there

# %%
agg_names = ['mean', 'median', 'var', 'min', 'max']


ml_columns = [col for group_col in [[sensor + '_' + agg for agg in agg_names] 
                                    for sensor in sensor_columns]
             for col in group_col]

# %%
sequence_df = pd.concat([full_data.groupby('sequence').agg({sensor: 
                                   agg_names}) for sensor in sensor_columns], 
                        axis = 1)
sequence_df.columns = ml_columns
sequence_df.head()
# Out:
#           sensor_00_mean  sensor_00_median  sensor_00_var  sensor_00_min  \
# sequence
# 0               0.041744         -0.148764       2.049649      -5.634467
# 1              -0.069294         -0.031298       2.540538      -6.657651
# 2              -0.001546          0.058733       1.316816      -2.797527
# 3               0.029869         -0.119784       3.131857      -3.643740
# 4               0.059132          0.005410       4.059335      -5.331530
#
#           sensor_00_max  sensor_01_mean  sensor_01_median  sensor_01_var  \
# sequence
# 0              7.534003       -0.013025          0.191702       2.277749
# 1              5.870943       -0.019958          0.001576       0.901366
# 2              3.402628        0.025000          0.120273       0.646229
# 3              4.856260       -0.049177          0.051471       3.666719
# 4              5.455951        0.014916          0.060399       1.918921
#
#           sensor_01_min  sensor_01_max  ...  sensor_11_mean  sensor_11_median  \
# sequence                                ...
# 0             -3.002101       3.623950  ...        0.010391          0.193416
# 1             -2.745798       2.525210  ...        0.199914          0.053498
# 2             -1.733193       2.321429  ...       -0.002932          0.083848
# 3             -5.860294       6.722689  ...       -0.026680         -0.175926
# 4             -5.898109       3.532563  ...       -0.099657         -0.115741
#
#           sensor_11_var  sensor_11_min  sensor_11_max  sensor_12_mean  \
# sequence
# 0              1.581850      -2.972222       2.989712       -1.286985
# 1              3.150006      -3.573045       8.044239       -1.604085
# 2              0.373490      -1.705761       1.475309        0.000945
# 3              1.958582      -3.837449       3.593621       -0.003708
# 4              8.378860      -7.439300       6.989712        0.000028
#
#           sensor_12_median  sensor_12_var  sensor_12_min  sensor_12_max
# sequence
# 0                -0.447997      67.352879     -50.658994       6.674766
# 1                -0.009591    2529.213697    -160.234442     144.598039
# 2                -0.004902       0.130360      -1.044331       1.116795
# 3                -0.012361       0.058423      -0.837170       0.593350
# 4                 0.002344       0.002663      -0.098465       0.135976
#
# [5 rows x 65 columns]

# %%
full_df = pd.merge(test_labels, sequence_df, on = 'sequence')
full_df.head()
# Out:
#    sequence  state  sensor_00_mean  sensor_00_median  sensor_00_var  \
# 0         0      0        0.041744         -0.148764       2.049649
# 1         1      1       -0.069294         -0.031298       2.540538
# 2         2      1       -0.001546          0.058733       1.316816
# 3         3      1        0.029869         -0.119784       3.131857
# 4         4      1        0.059132          0.005410       4.059335
#
#    sensor_00_min  sensor_00_max  sensor_01_mean  sensor_01_median  \
# 0      -5.634467       7.534003       -0.013025          0.191702
# 1      -6.657651       5.870943       -0.019958          0.001576
# 2      -2.797527       3.402628        0.025000          0.120273
# 3      -3.643740       4.856260       -0.049177          0.051471
# 4      -5.331530       5.455951        0.014916          0.060399
#
#    sensor_01_var  ...  sensor_11_mean  sensor_11_median  sensor_11_var  \
# 0       2.277749  ...        0.010391          0.193416       1.581850
# 1       0.901366  ...        0.199914          0.053498       3.150006
# 2       0.646229  ...       -0.002932          0.083848       0.373490
# 3       3.666719  ...       -0.026680         -0.175926       1.958582
# 4       1.918921  ...       -0.099657         -0.115741       8.378860
#
#    sensor_11_min  sensor_11_max  sensor_12_mean  sensor_12_median  \
# 0      -2.972222       2.989712       -1.286985         -0.447997
# 1      -3.573045       8.044239       -1.604085         -0.009591
# 2      -1.705761       1.475309        0.000945         -0.004902
# 3      -3.837449       3.593621       -0.003708         -0.012361
# 4      -7.439300       6.989712        0.000028          0.002344
#
#    sensor_12_var  sensor_12_min  sensor_12_max
# 0      67.352879     -50.658994       6.674766
# 1    2529.213697    -160.234442     144.598039
# 2       0.130360      -1.044331       1.116795
# 3       0.058423      -0.837170       0.593350
# 4       0.002663      -0.098465       0.135976
#
# [5 rows x 67 columns]

# %%
X = full_df.copy().drop(['sequence', 'state'], axis = 1)
y = full_df['state']

# %% [markdown]
# # Doing some ML

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA, SparsePCA, TruncatedSVD
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %%
numeric_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median")), ("scaler", RobustScaler())]
)

# %%
rf_pipe = Pipeline(
    steps=[("preprocessor", numeric_transformer), ("regressor", RandomForestRegressor())]
)

average = []

for i in range(1,6):

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    rf_pipe.fit(X_train, y_train)
    score = rf_pipe.score(X_test, y_test)
    
    average.append(score)
    
    print(f"Run {i} of Random Forest model score: {score:.3f}")
    
print(np.array(average).mean())
